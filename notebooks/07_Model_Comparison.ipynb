# %% [markdown]
# # Model Comparison
#
# ## Objective
#
# This notebook compares the performance of all trained regression models.
#
# The comparison is based on:
#
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - R² Score
#
# The model with the highest R² Score is selected as the final model.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = {
    "Model": [
        "Linear Regression",
        "Decision Tree",
        "Random Forest",
        "Gradient Boosting",
        "XGBoost"
    ],
    "R2 Score": [
        0.806847,
        0.781369,
        0.883370,
        0.901117,
        0.865995
    ]
}

results_df = pd.DataFrame(results)

results_df
# Out:
#                Model  R2 Score
# 0  Linear Regression  0.806847
# 1      Decision Tree  0.781369
# 2      Random Forest  0.883370
# 3  Gradient Boosting  0.901117
# 4            XGBoost  0.865995

# %%
results_df = results_df.sort_values(
    by="R2 Score",
    ascending=False
)

results_df
# Out:
#                Model  R2 Score
# 3  Gradient Boosting  0.901117
# 2      Random Forest  0.883370
# 4            XGBoost  0.865995
# 0  Linear Regression  0.806847
# 1      Decision Tree  0.781369

# %%
plt.figure(figsize=(8,5))

plt.bar(results_df["Model"], results_df["R2 Score"])

plt.title("Model Comparison")

plt.xlabel("Models")

plt.ylabel("R² Score")

plt.xticks(rotation=20)

plt.show()

# %%
best_model = results_df.iloc[0]

print("Best Model")

best_model
# Out:
# Best Model
# Model       Gradient Boosting
# R2 Score             0.901117
# Name: 3, dtype: object

# %% [markdown]
# # Conclusion
#
# The performance of multiple regression models was compared.
#
# Among all models, **Gradient Boosting Regressor** achieved the highest R² Score.
#
# Therefore, Gradient Boosting Regressor is selected as the final model for deployment.
